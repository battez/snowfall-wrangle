# %%
import pandas as pd
import numpy as np

# %%
# load in all csv in dir.
import glob 
path = r'.' 
all_csv = glob.glob(path + '/*.csv')

# this will be the master frame that holds each CSV eventually
frame = pd.DataFrame()
list_ = []
for file_ in all_csv:
    
    
    df = pd.read_csv(file_, index_col='GHCN ID', header=1)
    
    # remove some columns
    df.drop(df.columns[21:], axis=1, inplace=True)
    df.drop(df.columns[5:17], axis=1, inplace=True)
    df.drop(df.columns[[2]], axis=1, inplace=True)
    
    # add state in as a convenience
    state = file_.split('/')[-1:]
    df.insert(1, 'State', state[0][0:2])
    
    # fix the letter values, T is trace, M is missing(?) 
    df[df.columns[4:9]] = df[df.columns[4:9]].replace(['M', 'T'], 0.0)
    
    # now add this df to main dataframe
    list_.append(df)
    
frame = pd.concat(list_)
frame.head()
# Out:
#                         Station Name State      County  Latitude  Longitude  \
# GHCN ID
# USC00060227              BAKERSVILLE    CT  LITCHFIELD    -73.01      41.84
# USC00060299              BARKHAMSTED    CT  LITCHFIELD    -72.96      41.92
# US1CTHR0018           BERLIN 2.4 SSE    CT    HARTFORD    -72.76      41.58
# USC00060808  BRIDGEPORT-SUCCESS HILL    CT   FAIRFIELD    -73.16      41.20
# US1CTFR0009       BROOKFIELD 3.3 SSE    CT   FAIRFIELD    -73.39      41.44
#
#             Mar 13 Mar 14 Mar 15 Mar 16
# GHCN ID
# USC00060227    0.0    4.3   12.2      0
# USC00060299      0    4.0   12.0    0.0
# US1CTHR0018    0.0    5.7   18.5      0
# USC00060808    0.0    4.5    2.6    0.0
# US1CTFR0009    0.0    4.5    8.7      0

# %%
frame.groupby('State').last()
# Out:
#                 Station Name      County  Latitude  Longitude Mar 13 Mar 14  \
# State
# CT           WINSTED 2.6 NNW  LITCHFIELD    -73.09      41.96    0.0      0
# DE     WILMINGTON PORTER RES  NEW CASTLE    -75.54      39.77      0    3.0
# MA          YARMOUTH 2.3 SSE  BARNSTABLE    -70.20      41.68    0.0    0.0
# MD             WORTON 3.9 NW        KENT    -76.13      39.32      0      0
# ME                  WOODLAND  WASHINGTON    -67.40      45.16      0      0
# NH                 YORK POND        COOS    -71.33      44.50      0      0
# NJ          WOODSTOWN 0.6 NW       SALEM    -75.33      39.66    0.0      0
# NY           YOUNGSTOWN 2 NE     NIAGARA    -79.01      43.27    0.0    4.0
# PA       YORK SPRINGS 0.7 SE       ADAMS    -77.11      40.00    0.0   11.5
# RI                WOONSOCKET  PROVIDENCE    -71.49      41.98      0    0.5
# VA           YORKTOWN 6.8 SE        YORK    -76.45      37.15      0      0
# VT             WORCESTER 2 W  WASHINGTON    -72.58      44.37    0.0    0.0
#
#       Mar 15 Mar 16
# State
# CT         0      0
# DE       0.0    0.0
# MA       0.0    0.0
# MD         0      0
# ME      10.0      0
# NH         0      0
# NJ         0      0
# NY       3.5    0.1
# PA       4.6    0.0
# RI      10.0      0
# VA         0    0.0
# VT      15.5    3.5

# %%
frame['State'].value_counts()
# Out:
# NY    348
# PA    308
# VA    255
# NJ    215
# MD    139
# MA    131
# ME    117
# NH     96
# VT     81
# CT     42
# DE     24
# RI     16
# Name: State, dtype: int64
